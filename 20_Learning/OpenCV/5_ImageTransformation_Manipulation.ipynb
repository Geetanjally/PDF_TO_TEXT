# %% [markdown]
# # Image Transformation and Manipulation

# %% [markdown]
# ![image.png](attachment:92de54ac-9001-465f-a6fe-504eecb234b1.png)

# %% [markdown]
# ## Resizing and Scalling Images - cv2.resize()

# %% [markdown]
# ### small image good detection
# - resized = cv2.resize(src,dsize,fx,fy,interpolation)
#     - scr: source of image
#     - dsize: New image pixels(width,height)
#     - fx: scaled factors: they are optional
#     - fy: scaled factors: they are optional
#     - interpolation: optional- This is for pixels resize, Quality control
