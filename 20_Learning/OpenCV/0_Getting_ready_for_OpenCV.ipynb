# %% [markdown]
# # OpenCV: Open Source Computer Vision

# %%
# Do phase 0,1,2 and 5,6

# %% [markdown]
# ## PHASE 0

# %% [markdown]
# - 1990s or early 2000's when black and white movies come or image form
#
# issues are
# - Coding difficulty
# - Performance Isuue
# - Lack of Standardization

# %% [markdown]
# ![image.png](attachment:94bbda19-9d86-44e3-9459-6030c484565f.png)

# %% [markdown]
# ![image.png](attachment:008488c4-ad2d-48d2-a596-df927035adeb.png)
