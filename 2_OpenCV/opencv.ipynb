# %%
import cv2
print("✅ OpenCV version:", cv2.__version__)
# Out:
# ✅ OpenCV version: 4.12.0

# %%
# For .py

# import cv2

# # Read an image
# img = cv2.imread(r"G:\Project\PDF_TO_TEXT\output_images\Data Mining\page_1.jpg")  # put any image path here

# # Convert to grayscale
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# # Save and show
# cv2.imwrite("gray_sample.jpg", gray)
# cv2.imshow("Gray Image", gray)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# #For .ipynb
# import cv2
# from matplotlib import pyplot as plt

# # Read an image
# img = cv2.imread(r"G:\Project\PDF_TO_TEXT\output_images\Data Mining\page_1.jpeg")

# # Check if image loaded correctly
# if img is None:
#     print("⚠️ Image not found. Check the file path.")
# else:
#     # Convert to grayscale
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#     # Save grayscale image
#     cv2.imwrite("gray_sample.jpg", gray)

#     # Convert color from BGR → RGB for Matplotlib
#     img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#     # Display original and grayscale images side-by-side
#     plt.figure(figsize=(10, 5))

#     plt.subplot(1, 2, 1)
#     plt.imshow(img_rgb)
#     plt.title("Original Image")
#     plt.axis("off")

#     plt.subplot(1, 2, 2)
#     plt.imshow(gray, cmap='gray')
#     plt.title("Grayscale Image")
#     plt.axis("off")

#     plt.show()

# %%
# import cv2
# import os
# from matplotlib import pyplot as plt

# # Path to your folder containing all page images
# input_folder = r"G:\Project\PDF_TO_TEXT\1_pdf_to_image\output_images\Data Mining"
# output_folder = r"G:\Project\PDF_TO_TEXT\2_OpenCV\processed_images"

# # Create output folder if not exists
# os.makedirs(output_folder, exist_ok=True)

# # Get all image files (.jpg, .jpeg, .png)
# image_files = sorted([
#     f for f in os.listdir(input_folder)
#     if f.lower().endswith(('.jpg', '.jpeg', '.png'))
# ])

# # Check if folder has images
# if not image_files:
#     print("⚠️ No images found in the folder.")
# else:
#     for i, file_name in enumerate(image_files, start=1):
#         image_path = os.path.join(input_folder, file_name)
#         print(f"🖼️ Processing {i}/{len(image_files)}: {file_name}")

#         # Read and convert to grayscale
#         img = cv2.imread(image_path)
#         if img is None:
#             print(f"⚠️ Skipping {file_name} (cannot open)")
#             continue

#         gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#         # Save grayscale image
#         output_path = os.path.join(output_folder, f"gray_{file_name}")
#         cv2.imwrite(output_path, gray)

#         # Show one sample image (optional)
#         if i == 1:
#             plt.figure(figsize=(10, 5))
#             plt.subplot(1, 2, 1)
#             plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#             plt.title("Original")
#             plt.axis("off")

#             plt.subplot(1, 2, 2)
#             plt.imshow(gray, cmap='gray')
#             plt.title("Grayscale")
#             plt.axis("off")

#             plt.show()

#     print(f"\n✅ Processed {len(image_files)} images and saved to '{output_folder}'")
# Out:
# 🖼️ Processing 1/22: page_1.jpeg
# 🖼️ Processing 2/22: page_10.jpeg
# 🖼️ Processing 3/22: page_11.jpeg
# 🖼️ Processing 4/22: page_12.jpeg
# 🖼️ Processing 5/22: page_13.jpeg
# 🖼️ Processing 6/22: page_14.jpeg
# 🖼️ Processing 7/22: page_15.jpeg
# 🖼️ Processing 8/22: page_16.jpeg
# 🖼️ Processing 9/22: page_17.jpeg
# 🖼️ Processing 10/22: page_18.jpeg
# 🖼️ Processing 11/22: page_19.jpeg
# 🖼️ Processing 12/22: page_2.jpeg
# 🖼️ Processing 13/22: page_20.jpeg
# 🖼️ Processing 14/22: page_21.jpeg
# 🖼️ Processing 15/22: page_22.jpeg
# 🖼️ Processing 16/22: page_3.jpeg
# 🖼️ Processing 17/22: page_4.jpeg
# 🖼️ Processing 18/22: page_5.jpeg
# 🖼️ Processing 19/22: page_6.jpeg
# 🖼️ Processing 20/22: page_7.jpeg
# 🖼️ Processing 21/22: page_8.jpeg
# 🖼️ Processing 22/22: page_9.jpeg
#
# ✅ Processed 22 images and saved to 'G:\Project\PDF_TO_TEXT\2_OpenCV\processed_images'
