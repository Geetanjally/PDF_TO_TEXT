# %%
# from pdf2image import convert_from_path
# import os

# def pdf_to_images(pdf_path, output_folder='output_images', dpi=300, image_format='JPEG', poppler_path=None):
#     """
#     Converts each page of a PDF file into an image.
#     """
#     if not os.path.exists(output_folder):
#         os.makedirs(output_folder)

#     try:
#         pages = convert_from_path(
#             pdf_path,
#             dpi=dpi,
#             poppler_path=poppler_path
#         )
#     except Exception as e:
#         print(f"⚠️ Skipping {pdf_path} due to error: {e}")
#         return []

#     saved_images = []
#     for i, page in enumerate(pages):
#         image_path = os.path.join(output_folder, f'page_{i + 1}.{image_format.lower()}')
#         page.save(image_path, image_format)
#         saved_images.append(image_path)
#         print(f'   Saved {image_path}')

#     return saved_images


# def convert_all_pdfs_in_folder(input_folder, output_base=None, dpi=300, image_format='JPEG', poppler_path=None):
#     """
#     Converts all PDF files in the given folder to images.
#     Each PDF will have its own output subfolder.

#     Parameters:
#     - input_folder (str): Folder containing PDF files.
#     - output_base (str): Base folder where output subfolders will be created.
#                          Defaults to 'output_images' folder inside input_folder.
#     - dpi (int): Resolution of output images.
#     - image_format (str): Image format ('JPEG', 'PNG', etc.)
#     - poppler_path (str): Path to Poppler bin folder.
#     """
#     if output_base is None:
#         output_base = os.path.join(input_folder, 'output_images')

#     if not os.path.exists(output_base):
#         os.makedirs(output_base)

#     pdf_files = [f for f in os.listdir(input_folder) if f.lower().endswith('.pdf')]

#     if not pdf_files:
#         print("No PDF files found in the folder!")
#         return 0

#     total_converted = 0
#     for pdf_file in pdf_files:
#         pdf_path = os.path.join(input_folder, pdf_file)
#         pdf_name = os.path.splitext(pdf_file)[0]
#         output_folder = os.path.join(output_base, pdf_name)

#         print(f"\nConverting {pdf_file}...")
#         images = pdf_to_images(pdf_path, output_folder, dpi, image_format, poppler_path)
#         if images:
#             total_converted += 1

#     print(f"\n✅ All PDFs converted successfully! Total converted: {total_converted}")
#     return total_converted


# if __name__ == "__main__":
#     input_folder = r"G:\Project\PDF_TO_TEXT\0_Input_folder"
#     poppler_bin_path = r"C:\Users\HP\poppler-25.07.0\Library\bin"
#     convert_all_pdfs_in_folder(input_folder, poppler_path=poppler_bin_path)

# %%
# from IPython.display import Image, display
# import os

# # Assuming pdf_to_images function from before is already defined

# pdf_file = r'G:\Project\pdf_to_ppt\OOPS.pdf'
# image_files = pdf_to_images(pdf_file)

# # Display saved images in notebook
# for img_path in image_files:
#     display(Image(filename=img_path))

# %%
# !pdftoppm -h

# %%
# import subprocess

# cmd = [
#     r"C:\Users\HP\poppler-25.07.0\Library\bin\pdfinfo.exe",
#     r"G:\Project\PDF_TO_TEXT\0_Input_folder\resume_geetanjally_rani_repaired.pdf"
# ]

# result = subprocess.run(cmd, capture_output=True, text=True)
# print("Return Code:", result.returncode)
# print("Stdout:", result.stdout)
# print("Stderr:", result.stderr)

# %%
# from pdf2image import convert_from_path

# pdf_path = r"G:\Project\PDF_TO_TEXT\0_Input_folder\resume_final.pdf"

# try:
#     pages = convert_from_path(
#         pdf_path,
#         dpi=200,
#         poppler_path=r"C:\Users\HP\poppler-25.07.0\Library\bin"
#     )
#     print(f"✅ Successfully loaded {len(pages)} pages.")
# except Exception as e:
#     print(f"⚠️ Error: {e}")
